# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Power Spectrum

# %%
basedir = '/global/cfs/cdirs/desi/cosmosim/KP45/MC/Clustering/AbacusSummit/CubicBox/LRG/Pk/Post/nadathur/fiducial_settings/dk0.005/'

# %%
# Import the data
user = 'nadathur'
dk = 0.005

dat = 0

for ii in range(25):
    dat += 1./25 * np.loadtxt(basedir + 'LRG_snap20_ph0%02d.gcat_shift_MultiGrid_mesh512_smooth10_recsym_f0.838_b2.35.randoms_20X.Pk_nmesh512.txt'%(ii))

# %%
np.savetxt('pkells_recsym_mean_cubic.dat', np.array([dat[:100,1], dat[:100,3], dat[:100,4]]).T)

# %%
plt.plot(dat[:100,1], dat[:100,1]*dat[:100,3])
plt.plot(dat[:100,1], dat[:100,1]*dat[:100,4])

# %%
plt.plot(dat[:100,1], dat[:100,1]*dat[:100,3])
plt.plot(dat[:100,1], dat[:100,1]*dat[:100,4])

# %%
basedir = '/global/cfs/cdirs/desi/cosmosim/KP45/MC/Clustering/EZmock/CubicBox/LRG/Pk/jmena/nmesh_512/dk0.005/'
cov = np.loadtxt(basedir + 'cov.txt')

# %%
Ndat = 100
np.savetxt('pkells_recsym_cov_cubic.dat',  cov[:(2*Ndat),:(2*Ndat)])

# %% [markdown]
# Correlation function

# %%
filebase = '/global/cfs/cdirs/desi/cosmosim/KP45/MC/Clustering/AbacusSummit/CubicBox/LRG/Xi/Post/jmena/'

# %%
ss = np.loadtxt(filebase + '/s.txt')
nbins = len(ss)


x0s = np.loadtxt(filebase + '/Xi_0.txt'); x0 = np.mean(x0s,axis=1)
x2s = np.loadtxt(filebase + '/Xi_2.txt'); x2 = np.mean(x2s,axis=1)
x4s = np.loadtxt(filebase + '/Xi_4.txt')

# %%
np.savetxt('xiells_recsym_mean_cubic.dat', np.array([ss,x0,x2]).T)

# %%
plt.plot(ss, ss**2 * x0)

# %%
filebase = '/global/cfs/cdirs/desi/cosmosim/KP45/MC/Clustering/EZmock/CubicBox/LRG/Xi/jmena/'

# %%
cov = np.loadtxt(filebase + 'cov.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f98dc65b56e2> in <module>
# ----> 1 cov = np.loadtxt(filebase + 'cov.txt')
#
# NameError: name 'np' is not defined

# %%
Ndat = len(ss)
np.savetxt('xiells_recsym_cov_cubic.dat',  cov[:(2*Ndat),:(2*Ndat)])

# %%
ss.shape
# Out:
# (50,)

# %%
cov_dat = np.loadtxt('/global/cscratch1/sd/sfschen/CobayaBAO_DESI/data/abacus_cubicbox_lrg_recsym_xi_cov.dat')

# %%
Ndat = 50
np.savetxt('xiells_recsym_cov_cubic.dat',  cov_dat[:(2*Ndat),:(2*Ndat)])
