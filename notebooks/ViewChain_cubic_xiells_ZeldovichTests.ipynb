# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import sys
# Needed for the model class to work inside a Notebook.
os.environ["COBAYA_NOMPI"] = "True"

from cobaya.yaml          import yaml_load_file
from cobaya.samplers.mcmc import plot_progress
from cobaya.model         import get_model
from cobaya.samplers.mcmc import plot_progress
#
from getdist.mcsamples    import MCSamplesFromCobaya
from getdist.mcsamples    import loadMCSamples
import getdist.plots      as     gdplt
#
import os

# %%
info = yaml_load_file("yaml_ZeldovichTests/recsym_cubic_xiells_empirical_ds.yaml")
print(info['params'].keys())
print(info['output'])
# Out:
# dict_keys(['apar', 'aperp', 'B1_bao', 'F_bao', 'Spar', 'Sperp'])
# chains_ZeldovichTests/recsym_cubic_xiells_empirical_ds

# %%
plot_progress(info['output'],figure_kwargs={"figsize": (10,8)})
# Out:
# array([<AxesSubplot:ylabel='$R-1$'>, <AxesSubplot:ylabel='acc. rate'>],
#       dtype=object)

# %%
root = '/global/cscratch1/sd/sfschen/CobayaBAO_DESI/chains_ZeldovichTests/recsym_cubic_xiells_'

samples = loadMCSamples(root + 'am', no_cache=True, \
                        settings={'ignore_rows':0.5
                        })

samples_A = loadMCSamples(root + 'A', no_cache=True, \
                        settings={'ignore_rows':0.5
                        })

samples_f = loadMCSamples(root + 'f', no_cache=True, \
                        settings={'ignore_rows':0.5
                        })

samples_FoG = loadMCSamples(root + 'FoG', no_cache=True, \
                        settings={'ignore_rows':0.5
                        })

samples_emp = loadMCSamples(root + 'empirical_ds', no_cache=True, \
                        settings={'ignore_rows':0.5
                        })

# %%
samples_free = loadMCSamples(root + 'free', no_cache=True, \
                        settings={'ignore_rows':0.5
                        })

# %%
gdplot = gdplt.get_subplot_plotter(subplot_size=2.5)

params = ['apar', 'aperp', 'B1_bao', 'F_bao']

gdplot.triangle_plot([samples, samples_A, samples_f, samples_FoG, samples_free, samples_emp],\
                     params,\
                     filled=True,\
                     contour_lws=2, title_limit=0,\
                     alphas = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5],\
                     markers={'apar': 1.0, 'aperp':1.0, 'B1_bao': 1.1453427999999999, 'F_bao': 0.77740741},\
                     figure_kwargs={"figsize": (15,15)})

# %%
gdplot = gdplt.get_subplot_plotter(subplot_size=3.5)

gdplot.triangle_plot([samples_free],\
                     ['apar', 'aperp', 'B1_bao', 'F_bao','A', 'f_fac', 'SigmaFoG_bao'],\
                     filled=True,\
                     contour_lws=2, title_limit=1,\
                     alphas = [0.5, 0.5, 0.5, 0.5, 0.5],\
                     markers={'apar': 1.0, 'aperp':1.0, 'B1_bao': 1.1453427999999999, 'F_bao': 0.77740741},\
                     figure_kwargs={"figsize": (15,15)})

# %%
tabs = samples_emp.getParams()

bf = np.argmin(tabs.chi2)
bf_chi2 = tabs.chi2[bf]

bf_params = {}

for param in info['params'].keys():
    # Only add to list if sampled
    if 'ref' in info['params'][param].keys():
        bf_params[param] = getattr(tabs, param)[bf]
        
print(bf_params)
print(bf_chi2)
# Out:
# {'apar': 1.0002948, 'aperp': 0.99934256, 'B1_bao': 1.1724374, 'F_bao': 0.55366445}
# 0.95808938

# %%
chains = [samples, samples_A, samples_f, samples_FoG, samples_free, samples_emp]

for chain in chains:
    
    print(chain.getName())
    print(chain.getInlineLatex('apar'))
    print(chain.getInlineLatex('aperp'))
    print(chain.getCorrelationMatrix()[0,1])
    
    print('')
# Out:
# recsym_cubic_xiells_am
# \alpha_\parallel = 1.0000\pm 0.0091
# \alpha_\perp = 1.0002\pm 0.0051
# -0.42384166120377476
#
# recsym_cubic_xiells_A
# \alpha_\parallel = 0.99997\pm 0.0088
# \alpha_\perp = 0.9997\pm 0.0049
# -0.3842461639838217
#
# recsym_cubic_xiells_f
# \alpha_\parallel = 0.9999\pm 0.0089
# \alpha_\perp = 0.9999\pm 0.0050
# -0.4207210522508163
#
# recsym_cubic_xiells_FoG
# \alpha_\parallel = 1.0014\pm 0.0093
# \alpha_\perp = 1.0001\pm 0.0049
# -0.4129458716180493
#
# recsym_cubic_xiells_free
# \alpha_\parallel = 0.99998\pm 0.0091
# \alpha_\perp = 0.9999\pm 0.0051
# -0.4101038107392558
#
# recsym_cubic_xiells_empirical_ds
# \alpha_\parallel = 0.9996\pm 0.0089
# \alpha_\perp = 0.9994\pm 0.0051
# -0.4292281276887

# %%
tabs = samples_free.getParams()

bf = np.argmin(tabs.chi2)
bf_chi2 = tabs.chi2[bf]

bf_params = {}

for param in info['params'].keys():
    # Only add to list if sampled
    if 'ref' in info['params'][param].keys():
        bf_params[param] = getattr(tabs, param)[bf]
        
print(bf_params)
#print('logpost: ', (tabs.chi2 + 2*tabs.minuslogprior)[bf]/2)
#print("Reduced chi2:  ", bf_chi2 / ( 120  - len(bf_params)))
# Out:
# {'apar': 0.99898026, 'aperp': 1.0011313, 'B1_bao': 1.1496388000000002, 'F_bao': 0.79980485, 'SigmaFoG_bao': 3.0278852, 'A': 1.0566061000000002, 'f_fac': 0.87090189}

# %%
bf_chi2
# Out:
# 107.58446

# %%
samples.getCorrelationMatrix()[:4,:4]
# Out:
# array([[ 1.        , -0.42384166,  0.12498694, -0.23438294],
#        [-0.42384166,  1.        , -0.19851541,  0.09449498],
#        [ 0.12498694, -0.19851541,  1.        , -0.71961297],
#        [-0.23438294,  0.09449498, -0.71961297,  1.        ]])

# %%
import sys
sys.path.append('./lss_likelihood/')

# %%
model= get_model(info)
lik = model.likelihood['bao_zeldovich_likelihood_flex_am.ZeldovichBAOLikelihood']
# Out:
# WARNING:model:Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'stop_on_error']

# %%
model.logposterior(bf_params)
# Out:
# LogPosterior(logpost=-57.84349916816307, logpriors=[-4.051272514754915], loglikes=array([-53.79222665]), derived=[])

# %%
bf_params['apar'] = 1.0
bf_params['aperp'] = 1.0

model.logposterior(bf_params)
bf_obs = lik.get_best_fit()

lik.bf_thetas
# Out:
# array([ 0.00427065, -0.00750979,  0.00029243,  0.00450017, -0.00182573,
#        -0.00133897,  0.00221283,  0.00097848, -0.00268816,  0.0011941 ])

# %%
#tt = lik.bao_predict('bao', thetas=lik.linear_param_means)
#obs = lik.bao_observe(tt)

# %%
#M = lik.binmat

# %%
bf_params
# Out:
# {'apar': 1.0,
#  'aperp': 1.0,
#  'B1_bao': 1.1496388000000002,
#  'F_bao': 0.79980485,
#  'SigmaFoG_bao': 3.0278852,
#  'A': 1.0566061000000002,
#  'f_fac': 0.87090189}

# %%
#np.savetxt('r_theory.txt', tt[:,0])
#np.savetxt('binmat.txt', M)

# %%
rdats = lik.xdat
xi0dat = lik.y0dat
xi2dat = lik.y2dat

# %%
plt.figure(figsize=(10,5))


params = {'apar': 1.0,
 'aperp': 1.0,
 'B1_bao': 1.1453427999999999, 'F_bao': 0.77740741,\
 'SigmaFoG_bao': 0,
 'A': 1.0,
 'f_fac': 1.0}

params = dict(params)
params['A'] = 0.8

model= get_model(info)
lik = model.likelihood['bao_zeldovich_likelihood_flex_am.ZeldovichBAOLikelihood']
model.logposterior(params)
obs = np.array(lik.get_best_fit())

plt.plot(rdats, rdats**2 * obs[:50])
plt.plot(rdats, -rdats**2 * obs[50:])

# Vary A

params = {'apar': 1.0,
 'aperp': 1.0,
 'B1_bao': 1.1453427999999999, 'F_bao': 0.77740741,\
 'SigmaFoG_bao': 0,
 'A': 0.8,
 'f_fac': 1.0}

model= get_model(info)
lik = model.likelihood['bao_zeldovich_likelihood_flex_am.ZeldovichBAOLikelihood']
model.logposterior(params)
obs_A = np.array(lik.get_best_fit())

plt.plot(rdats, rdats**2 * obs_A[:50], 'C0--')
plt.plot(rdats, -rdats**2 * obs_A[50:], 'C1--')

# Vary f

params = {'apar': 1.0,
 'aperp': 1.0,
 'B1_bao': 1.1453427999999999, 'F_bao': 0.77740741,\
 'SigmaFoG_bao': 0,
 'A': 1.0,
 'f_fac': 0.8}

model= get_model(info)
lik = model.likelihood['bao_zeldovich_likelihood_flex_am.ZeldovichBAOLikelihood']
model.logposterior(params)
bf_obs = np.array(np.array(lik.get_best_fit()))

plt.plot(rdats, rdats**2 * bf_obs[:50], 'C0:')
plt.plot(rdats, -rdats**2 * bf_obs[50:], 'C1:')


# Vary SigmaFoG

params = {'apar': 1.0,
 'aperp': 1.0,
 'B1_bao': 1.1453427999999999, 'F_bao': 0.77740741,\
 'SigmaFoG_bao': 100.0,
 'A': 1.0,
 'f_fac': 1.0}

model= get_model(info)
lik = model.likelihood['bao_zeldovich_likelihood_flex_am.ZeldovichBAOLikelihood']
model.logposterior(params)
obs_FoG = np.array(lik.get_best_fit())

plt.plot(rdats, rdats**2 * obs_FoG[:50], 'C0-.')
plt.plot(rdats, -rdats**2 * obs_FoG[50:], 'C1-.')


plt.xlim(70,130)
plt.ylim(-10,80)
# Out:
# WARNING:model:Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# WARNING:model:Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# WARNING:model:Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# WARNING:model:Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'stop_on_error']
# (-10.0, 80.0)

# %%
params
# Out:
# {'apar': 1.0,
#  'aperp': 1.0,
#  'B1_bao': 1.1453427999999999,
#  'F_bao': 0.77740741,
#  'SigmaFoG_bao': 25.0,
#  'A': 1.0,
#  'f_fac': 1.0}

# %%
lik.Zel
# Out:
# {'R': 15.0,
#  'fz': 0.8315978342939394,
#  'klin': array([1.00000000e-03, 1.00461810e-03, 1.00925754e-03, ...,
#         9.90827380e+00, 9.95403124e+00, 1.00000000e+01]),
#  'pnw': array([1.69434769e+03, 1.70160031e+03, 1.70888196e+03, ...,
#         1.01147402e-01, 9.90352829e-02, 9.87661435e-02]),
#  'pw': array([ 6.27505901e-01,  6.68220320e-01,  7.09445939e-01, ...,
#          1.72592009e-05,  9.18936256e-04, -7.92723764e-06]),
#  'sigmas': (10.556307852555234,
#   9.45499094916356,
#   10.565115328400125,
#   13.777685164072894,
#   0.03123000341125935)}
